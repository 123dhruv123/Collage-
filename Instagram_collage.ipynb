# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread('top_left.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.imread('top_right.jpg')
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
img3 = cv2.imread('center.jpeg')
img3=cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
img4 = cv2.imread('bottom_left.jpg')
img4=cv2.cvtColor(img4,cv2.COLOR_BGR2RGB)
img5 = cv2.imread('bottom_right.jpg')
img5=cv2.cvtColor(img5,cv2.COLOR_BGR2RGB)


img1=cv2.resize(img1,(200,200))
img2=cv2.resize(img2,(200,200))
img3=cv2.resize(img3,(100,100))
img4=cv2.resize(img4,(200,200))
img5=cv2.resize(img5,(200,200))

h1, w1 = img1.shape[:2]
h2, w2 = img2.shape[:2]

#create empty matrix
vis = np.zeros((430,430,3), np.uint8)

#combine 2 images
vis[10:210,10:210,:3] = img1
vis[10:210,220:420,:3] = img2
# vis[100:300,100:300,:3]=img3
vis[220:420, 10:210,:3] = img4
vis[220:420, 220:420,:3] = img5
vis[110+45:330-55,105+50:325-50,:3]=outputImage
plt.imshow(vis)

# %%
outputImage = cv2.copyMakeBorder(
                 img3, 
                 top=10, 
                 bottom=10, 
                 left=10, 
                 right=10, 
                 borderType=cv2.BORDER_CONSTANT, 
              )

# %%
plt.imshow(outputImage)

# %%
output=vis.reshape((430*430,-1))
print(output.shape)
# Out:
# (184900, 3)

# %%
red,green,blue=output[:,0],output[:,1],output[:,2]

# %%
m={
    "r":red,
    "g":green,
    "b":blue
}
df=pd.DataFrame(m)
df.to_csv("output.csv",index=False)

# %%
print(vis.shape)
# Out:
# (430, 430, 3)
